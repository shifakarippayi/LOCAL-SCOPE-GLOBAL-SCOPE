# %% [markdown]
# **GLOBAL SCOPE AND LOCAL SCOPE**

# %%
# A Varible is only available from unsidee the reagion it is created this called scpe
#local scope
#A varible created inside a function belongs to the local scope of that function and can only used inside that function

# %% [markdown]
# **Local scope**

# %%
def myfunc():
  x=300
  print(x)

myfunn()
print(x)
#this is local scope
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-626363a47114> in <cell line: 5>()
#       3   print(x)
#       4
# ----> 5 myfunn()
#       6 print(x)
#
# NameError: name 'myfunn' is not defined

# %%
#the varibl x is not avalble outside the function but it is
available for any function inside thhe function

# %% [markdown]
# The local variable can be accessed from a function within the function

# %%
def myfunc():
  x=300
  def myinnerfunc():
    print(x)
  myinnerfunc()

myfunc()
# Out:
# 300

# %% [markdown]
# **Global scope**
#
# a varible created  in the main body of the python code is a global varible and blogs to the global scope
#
# global varible are available from within any scope ,global and local
#
# a varible created outside of a function is global and can be used by anyone

# %%
x=300
def myfunc():
  print(x)

myfunc()
print(x)
#this is global scope
# Out:
# 300
# 300

# %% [markdown]
# **Global keyword:**
#
#
# if you need to create a global varible,but are stuck in local scope,you can use the global keyword
#
# the global keyword makes the varible global

# %%
def myfunc():

  x=300

myfunc()

print(x)
# Out:
# 200

# %%
x=300

def myfunc():
  global x
  x=200

myfunc()

print(x)
print(x)
# Out:
# 200
# 200
